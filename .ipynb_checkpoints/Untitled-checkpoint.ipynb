# %%
import pandas as pd

# %%
df = pd.read_json("data/user/output_8.json", lines=True)

# %%
df
# Out:
#                id        name  gender      school  year_of_birth  \
# 0      U_12302838         吴振兴       0      南京理工大学            NaN
# 1      U_12302884         韦昌铭       0        东北大学            NaN
# 2      U_12302943   建管1902张泽恩       1                        NaN
# 3      U_12302950    建管1901王力       0                        NaN
# 4      U_12302964         罗光芬       0        沈阳大学            NaN
# ...           ...         ...     ...         ...            ...
# 99995  U_12869904   茉莉花318167       0                        NaN
# 99996  U_12869905          何超       0      重庆三峡学院            NaN
# 99997  U_12869906         钟冰斌       0  浙江交通职业技术学院            NaN
# 99998  U_12869907         路花洞       0                        NaN
# 99999  U_12869908  婷婷玉立327092       0                        NaN
#
#                                             course_order  \
# 0                                               [735364]
# 1                                               [681006]
# ...

# %%
df[df['num_watch_vid'] == 4153]
# Out:
#                id name  gender school  year_of_birth course_order  \
# 16790  U_12433114  梁永洲       1                   NaN     [879050]
#
#                  enroll_time  num_courses  num_watch_vid
# 16790  [2020-10-26 21:31:35]            1           4153

# %%
dict(sorted(df['num_watch_vid'].value_counts().to_dict().items()))
# Out:
# {0: 96266,
#  1: 929,
#  2: 619,
#  3: 400,
#  4: 306,
#  5: 225,
#  6: 169,
#  7: 168,
#  8: 125,
#  9: 101,
#  10: 96,
#  11: 63,
#  12: 69,
#  13: 56,
#  14: 35,
#  15: 32,
#  16: 30,
#  17: 23,
#  18: 24,
#  19: 9,
#  20: 20,
#  21: 13,
#  22: 14,
#  23: 13,
#  24: 6,
#  25: 4,
#  26: 12,
#  27: 9,
#  28: 8,
#  29: 3,
#  30: 6,
#  31: 5,
#  32: 6,
#  33: 3,
#  34: 5,
#  35: 1,
#  36: 4,
#  37: 4,
#  38: 1,
#  39: 7,
#  40: 1,
#  41: 2,
#  42: 1,
#  44: 3,
#  45: 4,
#  46: 1,
#  47: 5,
#  49: 2,
#  51: 3,
#  52: 2,
#  53: 1,
#  54: 3,
#  55: 1,
#  56: 2,
#  57: 2,
#  59: 1,
#  62: 2,
#  63: 1,
#  64: 2,
#  65: 2,
#  66: 1,
#  70: 1,
#  71: 1,
#  73: 1,
#  77: 1,
#  78: 1,
#  79: 1,
#  81: 2,
#  83: 2,
#  84: 1,
#  95: 1,
#  98: 1,
#  99: 1,
#  106: 1,
#  120: 1,
#  138: 1,
#  142: 1,
#  145: 1,
#  147: 2,
#  148: 1,
#  152: 1,
#  153: 1,
#  159: 1,
#  169: 2,
#  172: 1,
#  183: 1,
#  186: 1,
#  210: 2,
#  215: 1,
#  238: 1,
#  250: 1,
#  268: 1,
#  279: 1,
#  331: 1,
#  358: 1,
# ...

# %%
df = pd.read_json("data/user/course.json", lines=True)

# %%
s = "C_"+ "1886668"

# %%
x = df[df['id'] == "C_"+ "1886668"]

# %%
x['resource'].iloc[0]
# Out:
# [{'titles': ['第1章  绪论', '1.1  学习数值计算的重要性', '1.1.1 数值计算课程导引'],
#   'resource_id': 'V_5981764',
#   'chapter': '0'},
#  {'titles': ['第1章  绪论', '1.1  学习数值计算的重要性', '1.1.2  学习数值计算的重要性'],
#   'resource_id': 'V_5981765',
#   'chapter': '0.1'},
#  {'titles': ['第1章  绪论', '1.2  计算机中的数系与运算特点', '计算机的数系及对数的处理'],
#   'resource_id': 'V_5981768',
#   'chapter': '0.1'},
#  {'titles': ['第1章  绪论', '1.3  误差', '误差概念及函数误差'],
#   'resource_id': 'V_5981769',
#   'chapter': '0.2'},
#  {'titles': ['第1章  绪论', '1.3  误差', '第1章 前3节作业'],
#   'resource_id': 'Ex_5981770',
#   'chapter': '0.2.1'},
#  {'titles': ['第1章  绪论', '1.4  有效数字', '1.4.1 有效数字定义'],
#   'resource_id': 'V_5981771',
#   'chapter': '0.3'},
#  {'titles': ['第1章  绪论', '1.4  有效数字', '1.4.2 有效数字与误差的关系'],
#   'resource_id': 'V_5981772',
#   'chapter': '0.3.1'},
#  {'titles': ['第1章  绪论', '1.5  数值计算研究的内容', '1.5.1 数值计算研究的内容'],
#   'resource_id': 'V_5981774',
#   'chapter': '0.4'},
#  {'titles': ['第1章  绪论', '1.6  数值分析中常用的一些概念', '1.6.1  数值计算常用概念(1)'],
# ...
